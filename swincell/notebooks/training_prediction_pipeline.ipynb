# %% [markdown]
# # Model training

# %%
import matplotlib.pyplot as plt
import torch
import glob
from natsort import natsorted
from swincell.utils.utils import load_default_config
from swincell.utils.data_utils import split_dataset_folder, flow_generationd
from swincell.utils.device_utils import get_device

# import warnings
# warnings.filterwarnings('ignore')
# Out:
# /Users/giuseppericciardi/Desktop/code/SwinCell/.venv/lib/python3.10/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
# IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html

# %% [markdown]
# # Configure training parameters
#
# For this demo, the input image is downsampled by 2 along each dimension. (args.downsample_factor = 2)

# %%
device = get_device()
data_dir = '/Users/giuseppericciardi/Desktop/code/SwinCell-original/dataset/'
args =load_default_config()
args.data_dir=data_dir
args.dataset  = 'colon'
args.roi_x = 128
args.roi_y = 128
args.roi_z = 32
args.max_epochs = 200
args.a_min = 0
args.a_max = 255
args.save_logits = False
args.downsample_factor = 2 # downsample the input image if resolution is too high

# %%
image_files = natsorted(glob.glob(data_dir +'images/*tif*'))
mask_files = natsorted(glob.glob(data_dir +'labels/*tif*'))#

train_datalist, test_datalist = split_dataset_folder(image_files,mask_files, split_ratios=[0.8,0.2])
# train_datalist, val_datalist, test_datalist = split_dataset(data_dir, split_ratios=[0.6,0.2,0.2])
print(len(train_datalist),len(test_datalist))
# Out:
# 24 6

# %%
if args.dataset =='colon':
    
    img_shape= (1300,1030,129) #original shape
    img_reshape = (img_shape[0]//args.downsample_factor,img_shape[1]//args.downsample_factor,img_shape[2]//args.downsample_factor)
    img_reshape = tuple(int(e) for e in img_reshape)

elif args.dataset =='allen':

    img_shape=(900,600,64)
    img_reshape = (img_shape[0]//args.downsample_factor,img_shape[1]//args.downsample_factor,img_shape[2]//args.downsample_factor)
    img_reshape = tuple(int(e) for e in img_reshape)

elif args.dataset =='nanolive':

    img_shape=(512,512,96)
    img_reshape = (img_shape[0]//args.downsample_factor,img_shape[1]//args.downsample_factor,img_shape[2]//args.downsample_factor)
    img_reshape = tuple(int(e) for e in img_reshape)

else:
    raise Warning("dataset not defined")
    img_reshape = None

# %%
from monai import data, transforms
train_transform = transforms.Compose(
    [
        transforms.LoadImaged(keys=["image", "label"]),
        transforms.EnsureChannelFirstd(keys=["image", "label"]),
        transforms.Resized(keys=["image", "label"],spatial_size=img_reshape),
        # transforms.RandZoomd(keys=["image", "label"],prob=1,min_zoom=0.2,max_zoom=5),
        # transforms.Spacingd(
        #     keys=["image", "label"], pixdim=(args.space_x, args.space_y, args.space_z), mode=("bilinear", "nearest")
        # ),
        transforms.ScaleIntensityRanged(
            keys=["image"], a_min=0, a_max=255, b_min=0, b_max=1, clip=True
        ),
        transforms.RandSpatialCropSamplesd(
            keys=["image","label"],
            # roi_size=[64,64,32],
            roi_size=[args.roi_x,args.roi_y,args.roi_z],
            num_samples=2,
            random_center=True,
            random_size=False,
        ),
        flow_generationd(keys=["label"]),

        # transforms.RandScaleIntensityd(keys="image", factors=0.1, prob=0.1),
        # transforms.RandShiftIntensityd(keys="image", offsets=0.1, prob=0.1),
        transforms.ToTensord(keys=["image", "label"]),
    ]
)
test_transform = transforms.Compose(
    [
        transforms.LoadImaged(keys=["image"]),
        transforms.EnsureChannelFirstd(keys=["image"]),
        transforms.Resized(keys=["image", "label"],spatial_size=img_reshape),
        # transforms.AsDiscreted(keys=["label"],threshold=1),
        # transforms.AddChanneld(keys=["image", "label"]),
        # transforms.Resized(keys=["image", "label"],spatial_size=(512,512,96)),
        transforms.ScaleIntensityRanged(
            # keys=["image"], a_min=21000, a_max=31000, b_min=0, b_max=1, clip=True
            keys=["image"], a_min=0, a_max=255, b_min=0, b_max=1, clip=True
        ),
        transforms.ToTensord(keys=["image"]),
    ]
)

train_ds = data.Dataset(data=train_datalist, transform=train_transform)
train_loader = data.DataLoader(
        train_ds, batch_size=1, num_workers=2, sampler=None, drop_last=True
    )
test_ds = data.Dataset(data=test_datalist, transform=test_transform)
test_loader = data.DataLoader(
        test_ds, batch_size=1, num_workers=2, sampler=None, drop_last=True
)

# %% [markdown]
# ## visualize training data

# %%
N_samples = 4
fig, axes = plt.subplots(N_samples, 3,sharex=False, sharey=False, figsize=(12,8))
n=0

slice2view = int(args.roi_z//2)
for i in range(N_samples):
    datai = next(iter(train_loader))
    img2plot=datai['image']
    label2plot=datai['label']
    # print('img/label/2plot shape',img2plot.shape, label2plot.shape)

    top= torch.max(img2plot[0,0,:,:,:],dim=-1)[0].detach().cpu()

    mask0= label2plot[0,0,:,:,slice2view].detach().cpu()
    flow= label2plot[0,1:4,:,:,slice2view].detach().cpu().numpy().transpose(1, 2, 0)
    # print(mask0.shape,flow.shape)
    # print(flow.max(),flow.min())
    axes[i,0].imshow(img2plot[0,0,:,:,slice2view])
    axes[i,0].set_title('Raw')
    
    axes[i,1].imshow(mask0)
    axes[i,1].set_title('Label')

    axes[i,2].imshow(flow)
    axes[i,2].set_title('Flows')

    # axes[i,3].imshow(label2plot[0,1,:,:,slice2view].detach().cpu().numpy())
    # axes[i,3].set_title('Flows')
    # axes[i,4].imshow(label2plot[0,2,:,:,slice2view].detach().cpu().numpy())
    # axes[i,4].set_title('Flows')
    # axes[i,5].imshow(label2plot[0,3,:,:,slice2view].detach().cpu().numpy())
    # axes[i,5].set_title('Flows')
    for col in range(3):
      axes[i,col].axis('off')
# Out:
# /Users/giuseppericciardi/Desktop/code/SwinCell/.venv/lib/python3.10/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
# /Users/giuseppericciardi/Desktop/code/SwinCell/.venv/lib/python3.10/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0x9b3fc4c00): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0x9b3fc4c00): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xc68801400): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xc68801400): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0x9b3fc4a00): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0x9b3fc4a00): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xc68802000): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xc68802000): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xc68801400): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xc68801400): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xc68802000): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xc68802000): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0x9b3fc4c00): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0x9b3fc4c00): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0x9b3fc4a00): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0x9b3fc4a00): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xc68802a00): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xc68802a00): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xc68801a00): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xc68801a00): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0x9b3fc6400): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0x9b3fc6400): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0x9b3fc6400): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0x9b3fc6400): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xc68802a00): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xc68802a00): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xc68801a00): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xc68801a00): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0x9b3fc6800): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0x9b3fc6800): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0x9b3fc6800): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0x9b3fc6800): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.0..1.9999353].
# /Users/giuseppericciardi/Desktop/code/SwinCell/.venv/lib/python3.10/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
# /Users/giuseppericciardi/Desktop/code/SwinCell/.venv/lib/python3.10/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xa83f7e200): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xa83f7e200): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xad1d28e00): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xad1d28e00): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xa83f7e200): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xa83f7e200): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xad1d28e00): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xad1d28e00): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xad1d28e00): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xad1d28e00): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xad1d28e00): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xad1d28e00): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xa83f7e200): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xa83f7e200): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xa83f7e200): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xa83f7e200): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xad39de400): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xad39de400): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xad39de400): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xad39de400): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xa83f7e200): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xa83f7e200): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xa83f7e200): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xa83f7e200): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xad39de400): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xad39de400): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xad39de400): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xad39de400): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xa83f7e200): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xa83f7e200): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xa83f7e200): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xa83f7e200): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.9999988..2.0].
# /Users/giuseppericciardi/Desktop/code/SwinCell/.venv/lib/python3.10/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
# /Users/giuseppericciardi/Desktop/code/SwinCell/.venv/lib/python3.10/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xb39c88e00): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xb39c88e00): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0x9caf3f800): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0x9caf3f800): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xb39c88e00): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xb39c88e00): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0x9caf3fc00): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0x9caf3fc00): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0x9caf3f800): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0x9caf3f800): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0x9caf3fc00): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0x9caf3fc00): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xb39c88e00): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xb39c88e00): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xb39c88e00): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xb39c88e00): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0x9caf3f600): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0x9caf3f600): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0x9caf3fe00): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0x9caf3fe00): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xb39c89e00): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xb39c89e00): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xb39c89e00): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xb39c89e00): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0x9caf3f600): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0x9caf3f600): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0x9caf3fe00): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0x9caf3fe00): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xb39c89e00): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xb39c89e00): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xb39c89e00): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xb39c89e00): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.9999812..1.9999979].
# /Users/giuseppericciardi/Desktop/code/SwinCell/.venv/lib/python3.10/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
# /Users/giuseppericciardi/Desktop/code/SwinCell/.venv/lib/python3.10/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xa6502b600): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xa6502b600): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0x79a992800): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0x79a992800): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xa6502b400): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xa6502b400): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0x79a992200): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0x79a992200): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0x79a992800): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0x79a992800): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0x79a992200): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0x79a992200): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xa6502b600): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xa6502b600): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xa6502b400): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xa6502b400): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xa66c30a00): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xa66c30a00): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xa66c30800): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xa66c30800): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0x79a992800): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0x79a992800): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0x79a992200): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0x79a992200): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xa66c30a00): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xa66c30a00): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xa66c30800): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0xa66c30800): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0x79a992800): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0x79a992800): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0x79a992200): Tag 65000 has unsupported data type (5) for meta-data dictionary.
#
# WARNING: In /Users/svc-dashboard/D/P/ITKPythonPackage/ITK-source/ITK/Modules/IO/TIFF/src/itkTIFFImageIO.cxx, line 1266
# TIFFImageIO (0x79a992200): Tag 65001 has unsupported data type (5) for meta-data dictionary.
#
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.0..2.0].

# %%
from swincell.utils.utils import AverageMeter, load_model

from torch.nn import MSELoss,BCEWithLogitsLoss
from monai.losses import DiceLoss

model = load_model(args).to(device)

loss1 = MSELoss(reduction='mean')
loss2 = DiceLoss(to_onehot_y=False, sigmoid=True)
losses = [loss1,loss2]

optimizer = torch.optim.Adam(model.parameters(), lr=args.optim_lr, weight_decay=1e-5)

# %% [markdown]
# # Model training

# %%
from swincell.trainer import train_epoch, save_checkpoint
import time

train_losses = []
for epoch in range(args.max_epochs):
    epoch_time = time.time()
    train_loss, train_img_list = train_epoch(
            model, train_loader, optimizer, epoch=epoch, loss_func=losses, args=args
        )
    print(
                "Training  {}/{}".format(epoch, args.max_epochs - 1),
                "loss: {:.4f}".format(train_loss),
                "time {:.2f}s".format(time.time() - epoch_time),
            )
    train_losses.append(train_loss)
# Out:
# Epoch 0/1000 0/4 loss: 4.0810 time 22.93s
# Epoch 0/1000 1/4 loss: 4.5442 time 6.48s
# Epoch 0/1000 2/4 loss: 4.4793 time 14.86s
# Epoch 0/1000 3/4 loss: 4.2664 time 2.84s
# Training  0/999 loss: 4.2664 time 47.15s
# Epoch 1/1000 0/4 loss: 3.8871 time 20.61s
# Epoch 1/1000 1/4 loss: 3.8836 time 2.63s
# Epoch 1/1000 2/4 loss: 3.6368 time 9.50s
# Epoch 1/1000 3/4 loss: 3.3542 time 0.37s
# Training  1/999 loss: 3.3542 time 33.16s
# Epoch 2/1000 0/4 loss: 4.0123 time 32.03s
# Epoch 2/1000 1/4 loss: 4.0206 time 1.33s
# Epoch 2/1000 2/4 loss: 4.5083 time 39.63s
# Epoch 2/1000 3/4 loss: 4.0086 time 0.37s
# Training  2/999 loss: 4.0086 time 73.40s
# Epoch 3/1000 0/4 loss: 3.8250 time 29.79s
# Epoch 3/1000 1/4 loss: 4.0583 time 5.98s
# Epoch 3/1000 2/4 loss: 3.9270 time 17.66s
# Epoch 3/1000 3/4 loss: 3.8986 time 9.65s
# Training  3/999 loss: 3.8986 time 63.14s
# Epoch 4/1000 0/4 loss: 3.2406 time 27.91s
# Epoch 4/1000 1/4 loss: 2.6724 time 0.37s
# Epoch 4/1000 2/4 loss: 3.1488 time 30.60s
# Epoch 4/1000 3/4 loss: 3.2577 time 0.37s
# Training  4/999 loss: 3.2577 time 59.30s
# Epoch 5/1000 0/4 loss: 3.0815 time 23.16s
# Epoch 5/1000 1/4 loss: 3.4714 time 12.54s
# Epoch 5/1000 2/4 loss: 3.6509 time 21.21s
# Epoch 5/1000 3/4 loss: 3.3349 time 0.37s
# Training  5/999 loss: 3.3349 time 57.34s
# Epoch 6/1000 0/4 loss: 2.9050 time 17.73s
# Epoch 6/1000 1/4 loss: 2.6276 time 0.37s
# Epoch 6/1000 2/4 loss: 3.0165 time 29.23s
# Epoch 6/1000 3/4 loss: 3.0652 time 0.37s
# Training  6/999 loss: 3.0652 time 47.74s
# Epoch 7/1000 0/4 loss: 3.2050 time 25.89s
# Epoch 7/1000 1/4 loss: 3.4766 time 12.05s
# Epoch 7/1000 2/4 loss: 3.6855 time 23.77s
# Epoch 7/1000 3/4 loss: 3.3974 time 0.37s
# Training  7/999 loss: 3.3974 time 62.13s
# Epoch 8/1000 0/4 loss: 2.4714 time 22.08s
# Epoch 8/1000 1/4 loss: 2.9503 time 11.05s
# Epoch 8/1000 2/4 loss: 3.2066 time 21.37s
# Epoch 8/1000 3/4 loss: 3.1243 time 2.67s
# Training  8/999 loss: 3.1243 time 57.23s
# Epoch 9/1000 0/4 loss: 2.2234 time 15.75s
# Epoch 9/1000 1/4 loss: 2.9937 time 17.56s
# Epoch 9/1000 2/4 loss: 2.9988 time 4.47s
# Epoch 9/1000 3/4 loss: 2.7489 time 0.37s
# Training  9/999 loss: 2.7489 time 38.20s
# Epoch 10/1000 0/4 loss: 3.1962 time 31.62s
# Epoch 10/1000 1/4 loss: 3.2702 time 2.33s
# Epoch 10/1000 2/4 loss: 3.1174 time 21.35s
# Epoch 10/1000 3/4 loss: 3.0927 time 5.66s
# Training  10/999 loss: 3.0927 time 61.01s
# Epoch 11/1000 0/4 loss: 2.2533 time 20.34s
# Epoch 11/1000 1/4 loss: 2.4574 time 3.36s
# Epoch 11/1000 2/4 loss: 2.4262 time 11.79s
# Epoch 11/1000 3/4 loss: 2.6556 time 18.16s
# Training  11/999 loss: 2.6556 time 53.70s
# Epoch 12/1000 0/4 loss: 3.0164 time 33.17s
# Epoch 12/1000 1/4 loss: 2.6689 time 0.37s
# Epoch 12/1000 2/4 loss: 3.0987 time 35.24s
# Epoch 12/1000 3/4 loss: 2.9905 time 0.37s
# Training  12/999 loss: 2.9905 time 69.21s
# Epoch 13/1000 0/4 loss: 3.3392 time 35.17s
# Epoch 13/1000 1/4 loss: 3.0150 time 0.37s
# Epoch 13/1000 2/4 loss: 3.0616 time 29.58s
# Epoch 13/1000 3/4 loss: 2.9486 time 0.37s
# Training  13/999 loss: 2.9486 time 65.55s
# Epoch 14/1000 0/4 loss: 2.6672 time 26.42s
# Epoch 75/1000 1/4 loss: 1.4531 time 0.37s
# Epoch 75/1000 2/4 loss: 1.3854 time 6.96s
# Epoch 75/1000 3/4 loss: 1.6812 time 30.06s
# Training  75/999 loss: 1.6812 time 58.39s
# Epoch 76/1000 0/4 loss: 1.8923 time 30.56s
# Epoch 76/1000 1/4 loss: 1.8758 time 2.08s
# Epoch 76/1000 2/4 loss: 1.8347 time 22.60s
# Epoch 76/1000 3/4 loss: 1.8032 time 2.27s
# Training  76/999 loss: 1.8032 time 57.58s
# Epoch 77/1000 0/4 loss: 2.2604 time 36.29s
# Epoch 77/1000 1/4 loss: 2.2678 time 0.37s
# Epoch 77/1000 2/4 loss: 2.3253 time 35.14s
# Epoch 77/1000 3/4 loss: 2.1605 time 0.37s
# Training  77/999 loss: 2.1605 time 72.23s
# Epoch 78/1000 0/4 loss: 1.8215 time 27.16s
# Epoch 78/1000 1/4 loss: 1.7513 time 0.37s
# Epoch 78/1000 2/4 loss: 1.7449 time 19.83s
# Epoch 78/1000 3/4 loss: 1.8907 time 9.49s
# Training  78/999 loss: 1.8907 time 56.91s
# Epoch 79/1000 0/4 loss: 1.7418 time 28.55s
# Epoch 79/1000 1/4 loss: 1.6621 time 0.37s
# Epoch 79/1000 2/4 loss: 1.6785 time 21.58s
# Epoch 79/1000 3/4 loss: 1.5939 time 0.37s
# Training  79/999 loss: 1.5939 time 50.92s
# Epoch 80/1000 0/4 loss: 1.3933 time 22.81s
# Epoch 80/1000 1/4 loss: 1.4305 time 0.37s
# Epoch 80/1000 2/4 loss: 1.4839 time 16.57s
# Epoch 80/1000 3/4 loss: 1.5139 time 3.16s
# Training  80/999 loss: 1.5139 time 42.96s
# Epoch 81/1000 0/4 loss: 1.5448 time 28.09s
# Epoch 81/1000 1/4 loss: 1.6103 time 0.38s
# Epoch 81/1000 2/4 loss: 1.7281 time 28.91s
# Epoch 81/1000 3/4 loss: 1.5974 time 0.37s
# Training  81/999 loss: 1.5974 time 57.82s
# Epoch 82/1000 0/4 loss: 1.6648 time 28.93s
# Epoch 82/1000 1/4 loss: 1.8283 time 7.41s
# Epoch 82/1000 2/4 loss: 1.9368 time 25.61s
# Epoch 82/1000 3/4 loss: 1.8849 time 0.37s
# Training  82/999 loss: 1.8849 time 62.37s
# Epoch 83/1000 0/4 loss: 1.5908 time 22.02s
# Epoch 83/1000 1/4 loss: 1.7613 time 9.79s
# Epoch 83/1000 2/4 loss: 1.9746 time 25.96s
# Epoch 83/1000 3/4 loss: 1.9671 time 0.38s
# Training  83/999 loss: 1.9671 time 58.22s
# Epoch 84/1000 0/4 loss: 1.5997 time 24.79s
# Epoch 84/1000 1/4 loss: 1.4922 time 0.37s
# Epoch 84/1000 2/4 loss: 1.5241 time 19.75s
# Epoch 84/1000 3/4 loss: 1.5391 time 0.38s
# Training  84/999 loss: 1.5391 time 45.36s
# Epoch 85/1000 0/4 loss: 1.3181 time 16.35s
# Epoch 85/1000 1/4 loss: 1.4564 time 14.59s
# Epoch 136/1000 1/4 loss: 1.2174 time 0.37s
# Epoch 136/1000 2/4 loss: 1.4043 time 34.98s
# Epoch 136/1000 3/4 loss: 1.3744 time 0.38s
# Training  136/999 loss: 1.3744 time 58.08s
# Epoch 137/1000 0/4 loss: 1.3238 time 22.17s
# Epoch 137/1000 1/4 loss: 1.6650 time 17.45s
# Epoch 137/1000 2/4 loss: 1.8234 time 20.40s
# Epoch 137/1000 3/4 loss: 1.7685 time 0.97s
# Training  137/999 loss: 1.7685 time 61.05s
# Epoch 138/1000 0/4 loss: 1.1423 time 12.75s
# Epoch 138/1000 1/4 loss: 1.3615 time 20.47s
# Epoch 138/1000 2/4 loss: 1.4071 time 4.29s
# Epoch 138/1000 3/4 loss: 1.4879 time 24.49s
# Training  138/999 loss: 1.4879 time 62.07s
# Epoch 139/1000 0/4 loss: 1.2734 time 16.67s
# Epoch 139/1000 1/4 loss: 1.3732 time 7.74s
# Epoch 139/1000 2/4 loss: 1.5700 time 22.81s
# Epoch 139/1000 3/4 loss: 1.5378 time 0.38s
# Training  139/999 loss: 1.5378 time 47.67s
# Epoch 140/1000 0/4 loss: 1.3102 time 27.71s
# Epoch 140/1000 1/4 loss: 1.4088 time 2.86s
# Epoch 140/1000 2/4 loss: 1.4748 time 27.22s
# Epoch 140/1000 3/4 loss: 1.4857 time 0.37s
# Training  140/999 loss: 1.4857 time 58.23s
# Epoch 141/1000 0/4 loss: 1.5810 time 29.66s
# Epoch 141/1000 1/4 loss: 1.5359 time 3.85s
# Epoch 141/1000 2/4 loss: 1.4886 time 23.24s
# Epoch 141/1000 3/4 loss: 1.4587 time 0.37s
# Training  141/999 loss: 1.4587 time 57.18s
# Epoch 142/1000 0/4 loss: 1.7815 time 33.04s
# Epoch 142/1000 1/4 loss: 1.6918 time 0.37s
# Epoch 142/1000 2/4 loss: 1.6940 time 35.70s
# Epoch 142/1000 3/4 loss: 1.5871 time 0.38s
# Training  142/999 loss: 1.5871 time 69.56s
# Epoch 143/1000 0/4 loss: 1.3968 time 17.05s
# Epoch 143/1000 1/4 loss: 1.4041 time 9.85s
# Epoch 143/1000 2/4 loss: 1.4110 time 4.89s
# Epoch 143/1000 3/4 loss: 1.4367 time 17.60s
# Training  143/999 loss: 1.4367 time 49.45s
# Epoch 144/1000 0/4 loss: 1.9480 time 40.87s
# Epoch 144/1000 1/4 loss: 1.7304 time 0.38s
# Epoch 144/1000 2/4 loss: 1.7473 time 32.43s
# Epoch 144/1000 3/4 loss: 1.5951 time 0.38s
# Training  144/999 loss: 1.5951 time 74.12s
# got empty masks, returning zeros
# Epoch 145/1000 0/4 loss: 1.4474 time 26.50s
# Epoch 145/1000 1/4 loss: 1.3040 time 0.38s
# Epoch 145/1000 2/4 loss: 1.3516 time 17.98s
# Epoch 145/1000 3/4 loss: 1.4181 time 0.37s
# Training  145/999 loss: 1.4181 time 45.28s
# Epoch 146/1000 0/4 loss: 1.8000 time 38.34s
# Epoch 146/1000 1/4 loss: 1.6120 time 0.39s
# Epoch 177/1000 0/4 loss: 1.3038 time 27.75s
# Epoch 177/1000 1/4 loss: 1.2403 time 0.37s
# Epoch 177/1000 2/4 loss: 1.2228 time 6.76s
# Epoch 177/1000 3/4 loss: 1.3057 time 14.26s
# Training  177/999 loss: 1.3057 time 49.20s
# Epoch 178/1000 0/4 loss: 1.7074 time 36.78s
# Epoch 178/1000 1/4 loss: 1.6322 time 0.37s
# Epoch 178/1000 2/4 loss: 1.6659 time 31.87s
# Epoch 178/1000 3/4 loss: 1.6586 time 0.37s
# Training  178/999 loss: 1.6586 time 69.45s
# Epoch 179/1000 0/4 loss: 1.3999 time 30.44s
# Epoch 179/1000 1/4 loss: 1.3951 time 0.38s
# Epoch 179/1000 2/4 loss: 1.3284 time 18.15s
# Epoch 179/1000 3/4 loss: 1.2803 time 0.37s
# Training  179/999 loss: 1.2803 time 49.39s
# Epoch 180/1000 0/4 loss: 1.1119 time 20.59s
# Epoch 180/1000 1/4 loss: 1.2882 time 7.79s
# Epoch 180/1000 2/4 loss: 1.3742 time 22.79s
# Epoch 180/1000 3/4 loss: 1.4745 time 13.46s
# Training  180/999 loss: 1.4745 time 64.69s
# Epoch 181/1000 0/4 loss: 1.3818 time 34.97s
# Epoch 181/1000 1/4 loss: 1.3258 time 0.38s
# Epoch 181/1000 2/4 loss: 1.4555 time 29.49s
# Epoch 181/1000 3/4 loss: 1.5257 time 0.37s
# Training  181/999 loss: 1.5257 time 65.28s
# Epoch 182/1000 0/4 loss: 1.2098 time 21.49s
# Epoch 182/1000 1/4 loss: 1.2305 time 0.43s
# Epoch 182/1000 2/4 loss: 1.3377 time 24.58s
# Epoch 182/1000 3/4 loss: 1.4480 time 10.58s
# Training  182/999 loss: 1.4480 time 57.15s
# Epoch 183/1000 0/4 loss: 1.2499 time 25.63s
# Epoch 183/1000 1/4 loss: 1.4710 time 14.82s
# Epoch 183/1000 2/4 loss: 1.4113 time 8.20s
# Epoch 183/1000 3/4 loss: 1.4411 time 21.07s
# Training  183/999 loss: 1.4411 time 69.78s
# Epoch 184/1000 0/4 loss: 1.1626 time 20.24s
# Epoch 184/1000 1/4 loss: 1.2243 time 2.93s
# Epoch 184/1000 2/4 loss: 1.2646 time 24.60s
# Epoch 184/1000 3/4 loss: 1.2924 time 3.72s
# Training  184/999 loss: 1.2924 time 51.56s
# Epoch 185/1000 0/4 loss: 1.1537 time 22.47s
# Epoch 185/1000 1/4 loss: 1.2925 time 0.38s
# Epoch 185/1000 2/4 loss: 1.3041 time 18.22s
# Epoch 185/1000 3/4 loss: 1.2919 time 0.38s
# Training  185/999 loss: 1.2919 time 41.50s
# Epoch 186/1000 0/4 loss: 1.2698 time 24.15s
# Epoch 186/1000 1/4 loss: 1.3789 time 0.37s
# Epoch 186/1000 2/4 loss: 1.4213 time 28.52s
# Epoch 186/1000 3/4 loss: 1.3796 time 0.38s
# Training  186/999 loss: 1.3796 time 53.48s
# Epoch 187/1000 0/4 loss: 1.0926 time 12.04s
# Epoch 197/1000 2/4 loss: 1.3516 time 31.16s
# Epoch 197/1000 3/4 loss: 1.3657 time 0.38s
# Training  197/999 loss: 1.3657 time 53.68s
# Epoch 198/1000 0/4 loss: 1.1563 time 19.22s
# Epoch 198/1000 1/4 loss: 1.2018 time 11.35s
# Epoch 198/1000 2/4 loss: 1.3876 time 22.74s
# Epoch 198/1000 3/4 loss: 1.4225 time 0.38s
# Training  198/999 loss: 1.4225 time 53.75s
# Epoch 199/1000 0/4 loss: 1.3417 time 28.50s
# Epoch 199/1000 1/4 loss: 1.3738 time 1.82s
# Epoch 199/1000 2/4 loss: 1.3753 time 27.13s
# Epoch 199/1000 3/4 loss: 1.3552 time 0.37s
# Training  199/999 loss: 1.3552 time 57.88s
# Epoch 200/1000 0/4 loss: 1.1408 time 22.11s
# Epoch 200/1000 1/4 loss: 1.2988 time 8.57s
# Epoch 200/1000 2/4 loss: 1.4189 time 27.66s
# Epoch 200/1000 3/4 loss: 1.4319 time 1.97s
# Training  200/999 loss: 1.4319 time 60.36s
# Epoch 201/1000 0/4 loss: 1.2960 time 29.19s
# Epoch 201/1000 1/4 loss: 1.4194 time 0.64s
# Epoch 201/1000 2/4 loss: 1.3574 time 15.47s
# Epoch 201/1000 3/4 loss: 1.3862 time 17.51s
# Training  201/999 loss: 1.3862 time 62.86s
# Epoch 202/1000 0/4 loss: 1.3765 time 30.62s
# Epoch 202/1000 1/4 loss: 1.4006 time 0.38s
# Epoch 202/1000 2/4 loss: 1.4044 time 27.13s
# Epoch 202/1000 3/4 loss: 1.4651 time 0.38s
# Training  202/999 loss: 1.4651 time 58.58s
# Epoch 203/1000 0/4 loss: 1.3306 time 29.12s
# Epoch 203/1000 1/4 loss: 1.4785 time 2.01s
# Epoch 203/1000 2/4 loss: 1.5349 time 29.39s
# Epoch 203/1000 3/4 loss: 1.4918 time 0.37s
# Training  203/999 loss: 1.4918 time 60.96s
# Epoch 204/1000 0/4 loss: 1.0978 time 15.60s
# Epoch 204/1000 1/4 loss: 1.1997 time 8.06s
# Epoch 204/1000 2/4 loss: 1.2747 time 13.40s
# Epoch 204/1000 3/4 loss: 1.3167 time 14.93s
# Training  204/999 loss: 1.3167 time 52.05s
# Epoch 205/1000 0/4 loss: 1.1738 time 21.60s
# Epoch 205/1000 1/4 loss: 1.2926 time 12.35s
# got empty masks, returning zeros
# Epoch 205/1000 2/4 loss: 1.3509 time 13.19s
# Epoch 205/1000 3/4 loss: 1.3889 time 0.37s
# Training  205/999 loss: 1.3889 time 47.57s
# Epoch 206/1000 0/4 loss: 1.2947 time 27.31s
# Epoch 206/1000 1/4 loss: 1.2856 time 0.38s
# Epoch 206/1000 2/4 loss: 1.4316 time 34.80s
# Epoch 206/1000 3/4 loss: 1.3987 time 0.37s
# Training  206/999 loss: 1.3987 time 62.92s
# Epoch 207/1000 0/4 loss: 1.1912 time 23.93s
# Epoch 207/1000 1/4 loss: 1.1826 time 0.39s
# Epoch 217/1000 3/4 loss: 1.3735 time 0.37s
# Training  217/999 loss: 1.3735 time 49.33s
# Epoch 218/1000 0/4 loss: 1.2471 time 24.40s
# Epoch 218/1000 1/4 loss: 1.3945 time 10.81s
# Epoch 218/1000 2/4 loss: 1.2875 time 4.94s
# Epoch 218/1000 3/4 loss: 1.2494 time 15.16s
# Training  218/999 loss: 1.2494 time 55.37s
# Epoch 219/1000 0/4 loss: 1.0925 time 15.49s
# Epoch 219/1000 1/4 loss: 1.1224 time 10.46s
# Epoch 219/1000 2/4 loss: 1.2850 time 25.43s
# Epoch 219/1000 3/4 loss: 1.3161 time 4.09s
# Training  219/999 loss: 1.3161 time 55.53s
# Epoch 220/1000 0/4 loss: 1.5198 time 32.27s
# Epoch 220/1000 1/4 loss: 1.3822 time 0.37s
# Epoch 220/1000 2/4 loss: 1.5004 time 34.81s
# Epoch 220/1000 3/4 loss: 1.4074 time 0.37s
# Training  220/999 loss: 1.4074 time 67.88s
# Epoch 221/1000 0/4 loss: 1.2182 time 23.56s
# Epoch 221/1000 1/4 loss: 1.4525 time 14.34s
# Epoch 221/1000 2/4 loss: 1.3954 time 4.06s
# Epoch 221/1000 3/4 loss: 1.3714 time 17.40s
# Training  221/999 loss: 1.3714 time 59.43s
# Epoch 222/1000 0/4 loss: 1.2731 time 30.79s
# Epoch 222/1000 1/4 loss: 1.3091 time 0.87s
# Epoch 222/1000 2/4 loss: 1.3908 time 29.52s
# Epoch 222/1000 3/4 loss: 1.3700 time 0.37s
# Training  222/999 loss: 1.3700 time 61.60s
# Epoch 223/1000 0/4 loss: 1.1272 time 5.68s
# Epoch 223/1000 1/4 loss: 1.3250 time 22.17s
# Epoch 223/1000 2/4 loss: 1.3472 time 6.25s
# Epoch 223/1000 3/4 loss: 1.3017 time 15.25s
# Training  223/999 loss: 1.3017 time 49.44s
# Epoch 224/1000 0/4 loss: 1.1746 time 21.40s
# Epoch 224/1000 1/4 loss: 1.3842 time 18.56s
# Epoch 224/1000 2/4 loss: 1.4907 time 18.34s
# Epoch 224/1000 3/4 loss: 1.5255 time 10.21s
# Training  224/999 loss: 1.5255 time 68.57s
# Epoch 225/1000 0/4 loss: 1.5048 time 38.92s
# Epoch 225/1000 1/4 loss: 1.4798 time 0.38s
# Epoch 225/1000 2/4 loss: 1.4400 time 26.78s
# Epoch 225/1000 3/4 loss: 1.4587 time 0.37s
# Training  225/999 loss: 1.4587 time 66.50s
# Epoch 226/1000 0/4 loss: 1.3358 time 23.25s
# Epoch 226/1000 1/4 loss: 1.3579 time 4.63s
# Epoch 226/1000 2/4 loss: 1.3951 time 22.95s
# Epoch 226/1000 3/4 loss: 1.3791 time 0.37s
# Training  226/999 loss: 1.3791 time 51.26s
# Epoch 227/1000 0/4 loss: 1.5543 time 35.94s
# Epoch 227/1000 1/4 loss: 1.5887 time 1.47s
# Epoch 227/1000 2/4 loss: 1.4937 time 24.44s
# Epoch 227/1000 3/4 loss: 1.5748 time 14.18s
# Training  227/999 loss: 1.5748 time 76.10s
# Epoch 228/1000 0/4 loss: 1.2941 time 21.28s
# Epoch 228/1000 1/4 loss: 1.3220 time 7.93s
# Epoch 228/1000 2/4 loss: 1.4675 time 23.51s
# Epoch 228/1000 3/4 loss: 1.4469 time 2.69s
# Training  228/999 loss: 1.4469 time 55.47s
# Epoch 229/1000 0/4 loss: 1.2854 time 30.77s
# Epoch 229/1000 1/4 loss: 1.2238 time 0.37s
# Epoch 229/1000 2/4 loss: 1.4799 time 44.25s
# Epoch 229/1000 3/4 loss: 1.4375 time 0.37s
# Training  229/999 loss: 1.4375 time 75.82s
# Epoch 230/1000 0/4 loss: 1.3120 time 30.13s
# Epoch 230/1000 1/4 loss: 1.2470 time 0.37s
# Epoch 230/1000 2/4 loss: 1.2737 time 24.36s
# Epoch 230/1000 3/4 loss: 1.3365 time 6.07s
# Training  230/999 loss: 1.3365 time 60.99s
# Epoch 231/1000 0/4 loss: 1.0996 time 15.46s
# Epoch 231/1000 1/4 loss: 1.2510 time 18.15s
# Epoch 231/1000 2/4 loss: 1.2569 time 8.55s
# Epoch 231/1000 3/4 loss: 1.2616 time 17.57s
# Training  231/999 loss: 1.2616 time 59.80s
# Epoch 232/1000 0/4 loss: 1.3440 time 31.72s
# Epoch 232/1000 1/4 loss: 1.3113 time 0.39s
# Epoch 232/1000 2/4 loss: 1.2814 time 17.11s
# Epoch 232/1000 3/4 loss: 1.3007 time 0.37s
# Training  232/999 loss: 1.3007 time 49.65s
# Epoch 233/1000 0/4 loss: 1.2231 time 32.54s
# Epoch 233/1000 1/4 loss: 1.2484 time 0.38s
# Epoch 233/1000 2/4 loss: 1.2722 time 26.17s
# Epoch 233/1000 3/4 loss: 1.3662 time 5.67s
# Training  233/999 loss: 1.3662 time 64.82s
# Epoch 234/1000 0/4 loss: 1.2397 time 26.41s
# Epoch 234/1000 1/4 loss: 1.3427 time 8.41s
# Epoch 234/1000 2/4 loss: 1.3996 time 23.59s
# Epoch 234/1000 3/4 loss: 1.3816 time 5.92s
# Training  234/999 loss: 1.3816 time 64.37s
# Epoch 235/1000 0/4 loss: 1.3632 time 32.33s
# Epoch 235/1000 1/4 loss: 1.2704 time 0.39s
# Epoch 235/1000 2/4 loss: 1.3969 time 39.21s
# Epoch 235/1000 3/4 loss: 1.3216 time 0.37s
# Training  235/999 loss: 1.3216 time 72.37s
# Epoch 236/1000 0/4 loss: 1.2414 time 27.22s
# Epoch 236/1000 1/4 loss: 1.1720 time 0.37s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 7
#       5 for epoch in range(args.max_epochs):
#       6     epoch_time = time.time()
# ----> 7     train_loss, train_img_list = train_epoch(
#       8             model, train_loader, optimizer, epoch=epoch, loss_func=losses, args=args
#       9         )
#      10     print(
#      11                 "Training  {}/{}".format(epoch, args.max_epochs - 1),
#      12                 "loss: {:.4f}".format(train_loss),
#      13                 "time {:.2f}s".format(time.time() - epoch_time),
#      14             )
#      15     train_losses.append(train_loss)
#
# File /data/programs/swincell_root/swincell/trainer.py:20, in train_epoch(model, loader, optimizer, epoch, loss_func, args)
#      18 start_time = time.time()
#      19 run_loss = AverageMeter()
# ---> 20 for idx, batch_data in enumerate(loader):
#      21     if isinstance(batch_data, list):
#      22         data, target = batch_data
#
# File ~/anaconda3/envs/swincell/lib/python3.10/site-packages/torch/utils/data/dataloader.py:628, in _BaseDataLoaderIter.__next__(self)
#     625 if self._sampler_iter is None:
#     626     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     627     self._reset()  # type: ignore[call-arg]
# --> 628 data = self._next_data()
#     629 self._num_yielded += 1
#     630 if self._dataset_kind == _DatasetKind.Iterable and \
#     631         self._IterableDataset_len_called is not None and \
#     632         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/anaconda3/envs/swincell/lib/python3.10/site-packages/torch/utils/data/dataloader.py:1316, in _MultiProcessingDataLoaderIter._next_data(self)
#    1313     return self._process_data(data)
#    1315 assert not self._shutdown and self._tasks_outstanding > 0
# -> 1316 idx, data = self._get_data()
#    1317 self._tasks_outstanding -= 1
#    1318 if self._dataset_kind == _DatasetKind.Iterable:
#    1319     # Check for _IterableDatasetStopIteration
#
# File ~/anaconda3/envs/swincell/lib/python3.10/site-packages/torch/utils/data/dataloader.py:1282, in _MultiProcessingDataLoaderIter._get_data(self)
#    1278     # In this case, `self._data_queue` is a `queue.Queue`,. But we don't
#    1279     # need to call `.task_done()` because we don't use `.join()`.
#    1280 else:
#    1281     while True:
# -> 1282         success, data = self._try_get_data()
#    1283         if success:
#    1284             return data
#
# File ~/anaconda3/envs/swincell/lib/python3.10/site-packages/torch/utils/data/dataloader.py:1120, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#    1107 def _try_get_data(self, timeout=_utils.MP_STATUS_CHECK_INTERVAL):
#    1108     # Tries to fetch data from `self._data_queue` once for a given timeout.
#    1109     # This can also be used as inner loop of fetching without timeout, with
#    (...)
#    1117     # Returns a 2-tuple:
#    1118     #   (bool: whether successfully get data, any: data if successful else None)
#    1119     try:
# -> 1120         data = self._data_queue.get(timeout=timeout)
#    1121         return (True, data)
#    1122     except Exception as e:
#    1123         # At timeout and error, we manually check whether any worker has
#    1124         # failed. Note that this is the only mechanism for Windows to detect
#    1125         # worker failures.
#
# File ~/anaconda3/envs/swincell/lib/python3.10/multiprocessing/queues.py:113, in Queue.get(self, block, timeout)
#     111 if block:
#     112     timeout = deadline - time.monotonic()
# --> 113     if not self._poll(timeout):
#     114         raise Empty
#     115 elif not self._poll():
#
# File ~/anaconda3/envs/swincell/lib/python3.10/multiprocessing/connection.py:257, in _ConnectionBase.poll(self, timeout)
#     255 self._check_closed()
#     256 self._check_readable()
# --> 257 return self._poll(timeout)
#
# File ~/anaconda3/envs/swincell/lib/python3.10/multiprocessing/connection.py:424, in Connection._poll(self, timeout)
#     423 def _poll(self, timeout):
# --> 424     r = wait([self], timeout)
#     425     return bool(r)
#
# File ~/anaconda3/envs/swincell/lib/python3.10/multiprocessing/connection.py:931, in wait(object_list, timeout)
#     928     deadline = time.monotonic() + timeout
#     930 while True:
# --> 931     ready = selector.select(timeout)
#     932     if ready:
#     933         return [key.fileobj for (key, events) in ready]
#
# File ~/anaconda3/envs/swincell/lib/python3.10/selectors.py:416, in _PollLikeSelector.select(self, timeout)
#     414 ready = []
#     415 try:
# --> 416     fd_event_list = self._selector.poll(timeout)
#     417 except InterruptedError:
#     418     return ready
#
# KeyboardInterrupt:

# %%
# uncomment to save final model locally
# save_model_name = 'demo_model_12812832_otf_1000epoch_dsp2.pt'
# save_checkpoint(model, epoch, args,save_model_name, best_acc=0, optimizer=optimizer)
# Out:
# Saving checkpoint demo_model_12812832_otf_1000epoch_dsp2.pt

# %%
#plot loss
plt.plot(train_losses)
plt.xlabel('epoch', fontsize=14)
plt.ylabel('loss', fontsize=14)
plt.title('Training loss')
# Out:
# Text(0.5, 1.0, 'Training loss')

# %% [markdown]
# # For inference with pretrained models:
# uncomment to load pretrained and presaved models

# %%
# load pretrained model
# save_model_name = 'demo_model_12812832_otf.pt'
# model_dict = torch.load(save_model_name)["state_dict"]
# model.load_state_dict(model_dict)

# predefined_model_path = '/home/xzhang/Projects/swincell_backup/runs/colon_cellpose_swinunetr_128_128_32_v2_1_255_colon_30/foldNone/model_final.pt'
# model_dict = torch.load(predefined_model_path)["state_dict"]
# model.load_state_dict(model_dict)
# Out:
# <All keys matched successfully>

# %% [markdown]
# # Data inference with the trained model

# %%
import numpy as np
import os
infer_ROI = (256,256,32)
output_folder = data_dir + 'output/'
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# %%
test_transform = transforms.Compose(
        [
            transforms.LoadImaged(keys=["image", "label"]),
            transforms.EnsureChannelFirstd(keys=["image", "label"]),
            # flow_reshaped(keys=["label"]),
            transforms.Resized(keys=["image", "label"],spatial_size=img_reshape),
            transforms.ScaleIntensityRanged(
                keys=["image"], a_min=args.a_min, a_max=args.a_max, b_min=args.b_min, b_max=args.b_max, clip=True
            ),

            transforms.ToTensord(keys=["image", "label"]),
        ]
    )


test_ds = data.Dataset(data=test_datalist, transform=test_transform)
test_loader = data.DataLoader(
        test_ds, batch_size=1, sampler=None, drop_last=False
    )

# %%
from monai.transforms import (
    AsDiscrete,
    Activations,
)
from functools import partial
from monai.inferers import sliding_window_inference
import tifffile
from swincell.cellpose_dynamics import compute_masks

model_inferer = partial(
    sliding_window_inference,
    roi_size=infer_ROI,
    sw_batch_size=2,
    predictor=model,
    overlap=0.5,
    mode='gaussian'
)
post_sigmoid = Activations(sigmoid=True)
post_pred = AsDiscrete(argmax=False, threshold=0.5)
with torch.no_grad():
        for idx, batch_data in enumerate(test_loader):
            out_filename = test_datalist[idx]['image'].split('.')[0].split('/')[-1] +'_pred.tiff' 
            data_test = batch_data["image"]
            data_test = data_test.cuda(device)
    
            logits = model_inferer(data_test)         

            logits_out =  np.squeeze(logits.detach().cpu().numpy())
            

            logits_out[0] = post_pred(post_sigmoid(logits_out[0]))

            logits_out_transposed = np.transpose(logits_out,(0,3,2,1))
            flows = logits_out[1:4,:,:,:]
            if args.save_logits:
                tifffile.imwrite(output_folder +'/pred_logits_transposed,'+out_filename ,logits_out_transposed)
            
            # print(logits.shape, logits.max(),logits.min())
            masks_recon,p = compute_masks(logits_out_transposed[[3,2,1],:,:,:],logits_out_transposed[0,:,:,:],cellprob_threshold=0.4,flow_threshold=0.4, do_3D=True,min_size=2500//args.downsample_factor//args.downsample_factor, use_gpu=True)
            
            print(masks_recon.shape)
# Out:
# torch.Size([1, 1, 650, 515, 64])
# logits shape (4, 650, 515, 64)
# logits shape (4, 650, 515, 64)
# 4.015282 -3.5039515
# torch.Size([1, 4, 650, 515, 64]) metatensor(7.1327, device='cuda:0') metatensor(-3.5040, device='cuda:0')

# %% [markdown]
# # visualize prediction results

# %%
from swincell.utils.plot_utils import get_random_cmap
n_row = 2
fig, axes = plt.subplots(2, 2,sharex=False, sharey=False, figsize=(12,10))
img_shape = logits.shape
slice2view = int(img_shape[-1]//2)
print('slice to view',slice2view)
# datai = next(iter(test_loader))
img=np.squeeze(data_test.detach().cpu().numpy())
print(img.shape,logits_out.shape)
flow= logits_out[1:4]
flow_slice = flow[:,:,:,slice2view].transpose(1, 2, 0)
print(flow.shape)


axes[0,0].imshow(img[:,:,slice2view])
axes[0,0].set_title('Raw')

axes[0,1].imshow(logits_out[0,:,:,slice2view])
axes[0,1].set_title('Cell prob')

axes[1,0].imshow(flow_slice)
axes[1,0].set_title('Predicted flows')                                                                                       


axes[1,1].imshow(masks_recon[slice2view].T,cmap=get_random_cmap(30))
axes[1,1].set_title('Predicted Masks')

for i in range(2):
    for j in range(2):
        axes[i,j].axis('off')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# slice to view 32
# (650, 515, 64) (4, 650, 515, 64)
# (3, 650, 515, 64)

# %% [markdown]
# # empty cache

# %%
import torch, gc
gc.collect()
torch.cuda.empty_cache()
